# %% [markdown]
# 1.  What is hypothesis testing in statistics ?

# %%
'''
Hypothesis testing in statistics is a method used to assess a claim about a population parameter using sample data.
 It involves formulating a null hypothesis (a statement of no effect or no difference) and
 an alternative hypothesis (a statement of what the researcher believes to be true).
'''

# %% [markdown]
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis ?

# %%
'''
Null Hypothesis is the initial assumption, often stating no effect, no difference, or no relationship.
Alternative Hypothesis is the researcher's claim, contradicting the null hypothesis.
'''

# %% [markdown]
# 3.  What is the significance level in hypothesis testing, and why is it important ?

# %%
'''
The significance level in hypothesis testing is a critical component of hypothesis testing in statistics.
It represents the maximum probability of rejecting the null hypothesis when it is actually true.

It is important because it ensures research reliability, Controls the errors, Increases confidence in results,
and provides a standard framework for evaluating evidences and decision making about the hypothesis.
'''

# %% [markdown]
# 4. What does a P-value represent in hypothesis testing ?

# %%
'''
The P-value in hypothesis testing represents the probability of observing a test statistic atleast as extreme
 as the one observed, assuming that the null hypothesis is true.
'''

# %% [markdown]
# 5.  How do you interpret the P-value in hypothesis testing ?

# %%
'''
The P-value interpretation :

    1. Small p-value : Small p-value (< 0.05) indicates strong evidence against the null hypothesis,
suggesting that the observed results are unlikely to occur by chance.

    2. Large p-value : A Large p-value (> 0.05) indicates a weak evidence against the null hypothesis,
suggesting that the observed results maybe occur by chance.
'''

# %% [markdown]
# 6.  What are Type 1 and Type 2 errors in hypothesis testing ?

# %%
'''
In hypothesis testing, there are two types of errors:

Type1 error :  Rejecting a Null Hypothesis (H0) which is actually true, is called Type1 error.
     eg :  Convicting an innocent person.

Type2 errror :  Failing to reject a Null Hypothesis (H0) which is actually false, is called as Type2 error.
     eg :  Aquitting a guilty person.

'''

# %% [markdown]
# 7.  What is the difference between a one-tailed and a two-tailed test in hypothesis testing ?

# %%
'''
One - Tailed test :
      Tests for an effect in one specific direction. (eg., greater than or less than).
    The alternate hypothesis states a specific direction of the effect, (H1 : mu > mu0  or H1 : mu < mu0).
    The critical region is located in the one tail of the  distribution.

Two - Tailed test :
      Tests for an effect in both the direction. (eg., equal or not equal to).
    The alternate hypothesis does not specify the direction of the effect, (H1 : mu != mu0).
    The critical region is divided between both the tails of the  distribution.
'''

# %% [markdown]
# 8. What is the Z-test, and when is it used in hypothesis testing ?

# %%
'''
The Z-test is a statistical test used to determine whether a sample mean is significantly different
 from a known population mean.
It is used in hypothessis testing when
  i.  The population standard deviation is known.
 ii.  The sample size is larger (>= 30).
iii.  The population is assumed to be normally distributed.
'''

# %% [markdown]
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing ?

# %%
'''
The Z-score of a probability distribution can be calculated as :
        z-score = (s_mean - P_mean)/(P_std/√n)

  where, s_mean is the sample mean,
         P_mean is the population mean,
         P_std is the standard deviation of the population,
        and  n is the sample size.
'''

# %% [markdown]
# 10. What is the T-distribution, and when should it be used instead of the normal distribution ?

# %%
'''
T-Distribution  is a probability distribution used to estimate the mean of a normally distributed population.

It is used instead of the Normal distribution when the population standard deviaation is unknown or
when the sample size is small (i.e. smaller than 30).
'''

# %% [markdown]
# 11.  What is the difference between a Z-test and a T-test ?

# %%
'''
Z-Test is used when the Population standard deviation is known, and the sample size is typically larger ( >30).
T-Test is used when the Population standard deviation is unknown, or the sample size is smaller (< 30).

T-test uses the sample standard deviation (s) to estimate the population standard deviation.
Z-test assumes the distribution to be a Normal Distribution.
'''

# %% [markdown]
# 12.  What is the T-test, and how is it used in hypothesis testing ?

# %%
'''
The T-test is a statistical test used to determine whether there is a significant difference
 between the means of two groups or between a sample mean and a known population mean.

It is used in hypothesis testing to test about the population mean based on the sample data.

The steps are :
1. State the Null Hypothesis and the Alternate Hypothesis.
2. Choose the type of T-test.
3. Calculate the T- statistic.
4. Determine the p-value.
5. Interpret the results by comparing the p-value to the level of significance(alpha),
to detrmine whether to reject the null hypothesis.
'''

# %% [markdown]
# 13.  What is the relationship between Z-test and T-test in hypothesis testing ?

# %%
'''
Both Z-tests and T-tests are used in hypothesis testing to compare means, but they differ in
 their assumptions and when they are appropriate to use.
Z-tests are used when the population standard deviation is known and the sample size is large (generally n >= 30),
while T-tests are used when the population standard deviation is unknown and/or the sample size is small (generally n < 30).
'''

# %% [markdown]
# 14. What is a confidence interval, and how is it used to interpret statistical results ?

# %%
'''
Confidence interval (CI) is a range of values that is likely to contain the true value of
an unknown population parameter, such as a mean or proportion.
Confidence intervals can be used to assess statistical significance.
If a confidence interval for the difference between two groups does not contain zero,
  it suggests a statistically significant difference between those groups.
 For example, if a 95% confidence interval for the difference in means between two groups is (2, 5)
  it suggests that the true difference between the means is likely to be between 2 and 5,
   and this difference is statistically significant.
'''

# %% [markdown]
# 15. What is the margin of error, and how does it affect the confidence interval ?

# %%
'''
The margin of error is a statistic that expresses the amount of random sampling error in a survey result.
It's essentially a measure of how much the sample results might differ from the true population value.

The margin of error directly impacts the width of a confidence interval;
 a larger margin of error results in a wider confidence interval,
 and a smaller margin of error results in a narrower confidence interval.
'''

# %% [markdown]
# 16. How is Bayes' Theorem used in statistics, and what is its significance ?

# %%
'''
Bayes' Theorem  in probability and statistics, offers a way to update the probability of an event based on new evidence.
 It is widely applied in various statistical analyses, particularly in Bayesian inference,
 where prior beliefs are combined with new data to form posterior beliefs.

It allows for more accurate predictions and decisions by incorporating prior knowledge and
adjusting it with new data. Essentially, it helps in reasoning under uncertainty by refining
 our understanding of events as we gather more information.
'''

# %% [markdown]
# 17. What is the Chi-square distribution, and when is it used ?

# %%
'''
The Chi-square distribution is a probability distribution used in statistical inference,
particularly in hypothesis testing and confidence intervals.

It is used :
 To determine whether the observed frequencies fit expected distributions.
 To test for independence between two categorical variables.
 To test whether different populations have the same proportion of some characteristics.
'''

# %% [markdown]
# 18. What is the Chi-square goodness of fit test, and how is it applied ?

# %%
'''
The Chi-square goodness of fit test is used to determine whether the observed frequencies fit expected distributions.
Its various commomn applications are :
  Statistical modeling : To evaluate the fit of statistical models.
  Data Analysis : To understand the understand the underlying distribution of data.

The steps are :
   1. Formulate the Null Hypothesis.
   2. Collect and categorize data.
   3. Calculate expected frequencies.
   4. Calculate the test statistic.
   5. Determine the p-value.
'''

# %% [markdown]
# 19. What is the F-distribution, and when is it used in hypothesis testing ?

# %%
'''
The F-test is a statistical test used to compare the variance of two populations or
to test the overall significance of a regression model.
 It is used to determine whether two populations have equal variance.
 and to determine p-value based on the F-statistics and the degree of freedom.
'''

# %% [markdown]
# 20. What is an ANOVA test, and what are its assumptions ?

# %%
'''
ANOVA stands for Analysis of variance.
ANOVA test is a statistical technique used to compare the means among three or more groups.

Assumptions for Anova test are:
    Data should be normally distributed within each group.
    Equal VAriance across all the groups.
    Observations should be independent of each other.
'''

# %% [markdown]
# 21. What are the different types of ANOVA tests

# %%
'''
The different types of anova test are :
  1. One - Way Anova
  2. Two - way Anova
  3. Repeated measures Anova
  4. Factorial Anova
'''

# %% [markdown]
# 22. What is the F-test, and how does it relate to hypothesis testing?

# %%
'''
F-test is a statistical test that compares the variances of two or more samples or populations
 to determine if there's a significant difference between them.
It's commonly used in hypothesis testing to assess whether the differences observed in sample variances
are likely due to random chance or a true difference in the populations from which the samples were drawn.
'''

# %% [markdown]
# # PRACTICAL

# %% [markdown]
# 1.  Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

# %%
import math
import scipy.stats as st

def z_test(sample_mean, population_mean, population_std, sample_size, alpha=0.05):
  z_statistic = (sample_mean - population_mean) / (population_std / math.sqrt(sample_size))
  p_value = 2 * (1 - st.norm.cdf(abs(z_statistic)))
  reject_null = p_value < alpha
  return z_statistic, p_value, reject_null

def interpret_results(z_statistic, p_value, reject_null):
  print(f"Z-statistic: {z_statistic:.4f}")
  print(f"P-value: {p_value:.4f}")

  if reject_null:
    print("Reject the null hypothesis.")
    print("There is a statistically significant difference between the sample mean and the population mean.")
  else:
    print("Fail to reject the null hypothesis.")
    print("There is no statistically significant difference between the sample mean and the population mean.")

# %%
sample_mean = 78
population_mean = 75
population_std = 10
sample_size = 40
alpha = 0.05
z_statistic, p_value, reject_null = z_test(sample_mean, population_mean, population_std, sample_size, alpha)
interpret_results(z_statistic, p_value, reject_null)
# Out:
# Z-statistic: 1.8974
# P-value: 0.0578
# Fail to reject the null hypothesis.
# There is no statistically significant difference between the sample mean and the population mean.

# %% [markdown]
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

# %%
import numpy as np
from scipy import stats
np.random.seed(42)

group_a_data = np.random.normal(loc=10, scale=2, size=50)
group_b_data = np.random.normal(loc=11, scale=2, size=50)

t_statistic, p_value = stats.ttest_ind(group_a_data, group_b_data)

print(f"Simulated Data - Group A Mean: {np.mean(group_a_data):.2f}")
print(f"Simulated Data - Group B Mean: {np.mean(group_b_data):.2f}")
print(f"Calculated T-statistic: {t_statistic:.2f}")
print(f"Calculated P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print(f"Since p-value ({p_value:.4f}) < alpha ({alpha}), reject the null hypothesis.")
    print("There is statistically significant evidence to suggest a difference in means between Group A and Group B.")
else:
    print(f"Since p-value ({p_value:.4f}) >= alpha ({alpha}), fail to reject the null hypothesis.")
    print("There is no statistically significant evidence to suggest a difference in means between Group A and Group B.")
# Out:
# Simulated Data - Group A Mean: 9.55
# Simulated Data - Group B Mean: 11.04
# Calculated T-statistic: -4.11
# Calculated P-value: 0.0001
# Since p-value (0.0001) < alpha (0.05), reject the null hypothesis.
# There is statistically significant evidence to suggest a difference in means between Group A and Group B.

# %% [markdown]
# 3.  Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

# %%
def one_sample_z_test(sample_data, population_mean, population_std_dev, alpha=0.05):
  sample_mean = np.mean(sample_data)
  sample_size = len(sample_data)
  z_statistic = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))
  p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))
  if p_value < alpha:
    print("Reject the null hypothesis. The sample mean is significantly different from the population mean.")
  else:
    print("Fail to reject the null hypothesis. There is no significant difference between the sample mean and the population mean.")
    return z_statistic, p_value, conclusion

# %%
sample = np.array([78, 82, 75, 85, 80, 79, 81, 83, 77, 84, 76, 80, 82, 79, 81, 78, 83, 77, 80, 82,
                       75, 85, 80, 79, 81, 83, 77, 84, 76, 80, 82, 79, 81, 78, 83, 77, 80, 82, 75, 85])
p_mean = 90
p_std = 10

one_sample_z_test(sample,p_mean,p_std)
# Out:
# Reject the null hypothesis. The sample mean is significantly different from the population mean.

# %% [markdown]
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

sample_mean = 52
hypothesized_mu = 50
population_std = 10
sample_size = 100
alpha = 0.05

standard_error = population_std / np.sqrt(sample_size)
z_statistic = (sample_mean - hypothesized_mu) / standard_error

critical_value_lower = stats.norm.ppf(alpha / 2)
critical_value_upper = stats.norm.ppf(1 - (alpha / 2))

print(f"Calculated Z-statistic: {z_statistic:.2f}")
print(f"Critical Z-values (lower, upper): {critical_value_lower:.2f}, {critical_value_upper:.2f}")

if z_statistic < critical_value_lower or z_statistic > critical_value_upper:
    print("Decision: Reject the Null Hypothesis (H0).")
    print("There is sufficient evidence to suggest the population mean is significantly different from the hypothesized mean.")
else:
    print("Decision: Fail to Reject the Null Hypothesis (H0).")
    print("There is not enough evidence to suggest the population mean is significantly different from the hypothesized mean.")
# Out:
# Calculated Z-statistic: 2.00
# Critical Z-values (lower, upper): -1.96, 1.96
# Decision: Reject the Null Hypothesis (H0).
# There is sufficient evidence to suggest the population mean is significantly different from the hypothesized mean.

# %%
x = np.linspace(-4, 4, 500)
pdf = stats.norm.pdf(x, 0, 1)
plt.figure(figsize=(10, 6))
plt.plot(x, pdf, color='blue', label='Standard Normal Distribution')

x_reject_lower = x[x < critical_value_lower]
pdf_reject_lower = pdf[x < critical_value_lower]
plt.fill_between(x_reject_lower, 0, pdf_reject_lower, color='red', alpha=0.3, label='Rejection Region (Lower)')

x_reject_upper = x[x > critical_value_upper]
pdf_reject_upper = pdf[x > critical_value_upper]
plt.fill_between(x_reject_upper, 0, pdf_reject_upper, color='red', alpha=0.3, label='Rejection Region (Upper)')

plt.axvline(z_statistic, color='green', linestyle='--', label=f'Calculated Z-statistic: {z_statistic:.2f}')

plt.axvline(critical_value_lower, color='purple', linestyle=':', label=f'Critical Z-value (Lower): {critical_value_lower:.2f}')
plt.axvline(critical_value_upper, color='purple', linestyle=':', label=f'Critical Z-value (Upper): {critical_value_upper:.2f}')

plt.title('Two-Tailed Z-Test: Decision Region Visualization')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def error_type(mu0,mu1,sigma,n,alpha):
  critical_value = norm.ppf(1-alpha,loc=mu0,scale=sigma/np.sqrt(n))

  #alpha
  type1_error = 1-norm.cdf(critical_value,loc=mu0,scale=sigma/np.sqrt(n))
  #beta
  type2_error = norm.cdf(critical_value,loc=mu1,scale=sigma/np.sqrt(n))

  power = 1-type2_error

  return type1_error,type2_error,power,critical_value

# %%
#Visualisation

def visualise_errors(mu0,mu1,sigma,n,alpha,critical_value):
  x= np.linspace(mu0-3*sigma/np.sqrt(n), mu1+3*sigma/np.sqrt(n),100)

  plt.plot(x,norm.pdf(x,loc=mu0,scale=sigma/np.sqrt(n)),label= "Null Hypothesis")
  plt.plot(x,norm.pdf(x,loc=mu1,scale=sigma/np.sqrt(n)),label = "Alternate Hypothesis")

  plt.axvline(critical_value,color = "r",label="Critical Value")
  plt.fill_between(x,norm.pdf(x,loc=mu0,scale=sigma/np.sqrt(n)),where=(x>critical_value),alpha=0.3,label='Type1 Error')
  plt.fill_between(x,norm.pdf(x,loc=mu1,scale=sigma/np.sqrt(n)),where=(x>critical_value),alpha=0.3,label='Type1 Error')

  plt.legend()
  plt.show()

# %%
#example

mu0 = 0
mu1 = 1
sigma = 1
n=100
alpha = 0.05

type1_error,type2_error,power,critical_value = error_type(mu0,mu1,sigma,n,alpha)
print("Type1 error : ",type1_error)
print("Type2 error : ",type2_error)
print("POWER : ",power)
print('Critical Value : ',critical_value)
# Out:
# Type1 error :  0.050000000000000044
# Type2 error :  3.267581289082612e-17
# POWER :  1.0
# Critical Value :  0.16448536269514724

# %%
visualise_errors(mu0,mu1,sigma,n,alpha,critical_value)

# %% [markdown]
# 6. Write a Python program to perform an independent T-test and interpret the results.

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

np.random.seed(0)
sample1 = np.random.normal(loc=5, scale = 2,size = 30)
sample2 = np.random.normal(loc=6, scale = 2,size = 30)

t_stat,p_value = stats.ttest_ind(sample1,sample2)
print("p - value : ",p_value)
print("T statistic : ",t_stat)
# Out:
# p - value :  0.37730145339434673
# T statistic :  0.889701920750517

# %%
alpha = 0.05

if p_value < alpha:
  print("Reject the Null Hypothesis. The two samples are significantly different.")
else :
  print("Failed to reject the Null Hypothesis. The two samples are not significantly different.")
# Out:
# Failed to reject the Null Hypothesis. The two samples are not significantly different.

# %% [markdown]
# 7. Perform a paired sample T-test using Python and visualize the comparison results.

# %%
bp_before = np.array([140, 155, 148, 160, 135, 150, 142, 158, 145, 152])
bp_after = np.array([135, 150, 140, 155, 130, 145, 138, 150, 140, 148])
t_statistic, p_value = stats.ttest_rel(bp_before, bp_after)
print(f"T-statistic: {t_statistic:.2f}")
print(f"P-value: {p_value:.3f}")

import pandas as pd
data = pd.DataFrame({'Before': bp_before, 'After': bp_after})

plt.figure(figsize=(8, 6))
for i in range(len(data)):
  plt.plot([1, 2], [data['Before'][i], data['After'][i]], marker='o', color='b', alpha=0.6)
plt.xticks([1, 2], ['Before', 'After'])
plt.ylabel('Blood Pressure')
plt.title('Paired Sample Comparison (Before vs. After)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# T-statistic: 11.94
# P-value: 0.000

# %% [markdown]
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

# %%
import numpy as np
from scipy import stats

np.random.seed(0)
sample_size = 100
p_mean = 100
p_std = 2
sample = np.random.normal(loc=p_mean, scale=p_std,size = sample_size)

H0 = "The sample mean is equal to Population mean."
HA = "The sample mean is not equal to population mean."

#z-test
s_mean = np.mean(sample)
z_stat = (s_mean - p_mean)/(p_std/np.sqrt(sample_size))
p_value_z = 2*(1- stats.norm.cdf(np.abs(z_stat)))

#t-test
t_stat,p_value_t = stats.ttest_1samp(sample,p_mean)

print("Z-test Results : \nZ-statistics : ",z_stat)
print("p-value : ",p_value_z )
print("\nT-test Results : \nT-statistics : ",t_stat)
print("p-value : ",p_value_t )
# Out:
# Z-test Results :
# Z-statistics :  0.598080155344789
# p-value :  0.5497864508624575
#
# T-test Results :
# T-statistics :  0.5904283402851094
# p-value :  0.5562489158695076

# %%
#Comparing the values
alpha = 0.05
if p_value_z < alpha:
  if p_value_t < alpha:
    print("Both Z-test and T-test reject the null Hypothesis.")
  else :
    print(" Only Z-test rejects the null hypothesis")
else:
  if p_value_t < alpha:
    print("Both T-test rejects the null hypothesis ")
  else :
    print("Both Z-test and T-test failed to reject the null Hypothesis.")
# Out:
# Both Z-test and T-test failed to reject the null Hypothesis.

# %% [markdown]
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %%
np.random.seed(0)
sample_size = 100
p_mean = 15
p_std = 5
sample = np.random.normal(loc=p_mean, scale=p_std,size = sample_size)

s_mean = np.mean(sample)
s_std = np.std(sample,ddof = 1)
standard_error = s_std /np.sqrt(sample_size)

confidence_level = 0.95
critical_value = stats.t.ppf((1+confidence_level)/2, df=sample_size-1)
margin_of_error = critical_value*standard_error

lower_bound = s_mean - margin_of_error
upper_bound = s_mean + margin_of_error

# %%
print("Sample mean : ",s_mean)
print(f"{confidence_level*100}% Confidence interval : ({lower_bound},{upper_bound})" )

#Significance
print("The Confidence Interval provides a range of values within which the true population mean is likely to lie.")
# Out:
# Sample mean :  15.299040077672425
# 95.0% Confidence interval : (14.294074104982982,16.304006050361867)
# The Confidence Interval provides a range of values within which the true population mean is likely to lie.

# %% [markdown]
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
np.random.seed(0)
sample_size = 100
p_mean = 15
p_std = 5
sample = np.random.normal(loc=p_mean, scale=p_std,size = sample_size)

s_std = np.std(sample,ddof = 1)

confidence_level = 0.95
critical_value = stats.t.ppf((1+confidence_level)/2, df=sample_size-1)
margin_of_error = critical_value*standard_error

# %%
print("Sample standard deviation : ",s_std)
print(f"The critical value for {confidence_level*100}% Confidence interval : {critical_value}")
print(f"The margin of error for {confidence_level*100}% Confidence interval : {margin_of_error}" )
# Out:
# Sample standard deviation :  5.064798846342509
# The critical value for 95.0% Confidence interval : 1.9842169515086827
# The margin of error for 95.0% Confidence interval : 1.0049659726894427

# %% [markdown]
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def prior(theta):
  return norm.pdf(theta,loc=0,scale=1)

def likelihood(data,theta):
  return norm.pdf(data,loc=theta)

def posterior(data,theta):
  likelihood_values = likelihood(data,theta)
  posterior_value = np.sum(np.log(likelihood_values)) + np.log(prior(theta))
  return posterior_value

np.random.seed(0)
theta_true = 2
data = np.random.normal(loc = theta_true,size=100)

theta_values = np.linspace(-5,5,100)
posterior_value = np.array([posterior(data,theta) for theta in theta_values])

posterior_probabilities = np.exp(posterior_value-np.max(posterior_value))
posterior_probabilities /= np.sum(posterior_probabilities)

# %%
plt.plot(theta_values,posterior_probabilities)
plt.title("Posterior Distribution")
plt.xlabel('Theta')
plt.ylabel("Posterior Probability")
plt.show()

map_estimate = theta_values[np.argmax(posterior_probabilities)]
print(f"MAP Estimate : {map_estimate}")
# Out:
# MAP Estimate : 2.070707070707071

# %% [markdown]
# 12. Perform a Chi-square test for independence between two categorical variables in Python.

# %%
import numpy as np
from scipy.stats import chi2_contingency
import pandas as pd

data = np.array([[20,15],[10,25]])

chi2,p,dof,expected = chi2_contingency(data)

print("Chi-square Statistics : ",chi2)
print("p-value : ",p)
print("Degree of Freedom : ",dof)
print("Expected Frequencies : ")
print(expected)
# Out:
# Chi-square Statistics :  4.725
# p-value :  0.029727183306054526
# Degree of Freedom :  1
# Expected Frequencies :
# [[15. 20.]
#  [15. 20.]]

# %%
alpha = 0.05
if p < alpha:
  print("Reject the null hypothesis. The variables are likely dependent.")
else:
  print("Failed to reject the null hypothesis. The variables are likely independent.")
# Out:
# Reject the null hypothesis. The variables are likely dependent.

# %% [markdown]
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.

# %%
import numpy as np

observed = np.array([[20,15],[10,25]])
row_totals = np.sum(observed,axis = 1)
column_totals = np.sum(observed,axis=0)

total = np.sum(observed)

expected = np.outer(row_totals,column_totals)/total

print("Observed Frequencies :\n",observed)
print("\nExpected Frequencies :\n",expected)
# Out:
# Observed Frequencies :
#  [[20 15]
#  [10 25]]
#
# Expected Frequencies :
#  [[15. 20.]
#  [15. 20.]]

# %% [markdown]
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
import numpy as np
from scipy.stats import chisquare

observed = np.array([20,15,10,30,25])
expected = np.array([20,20,20,20,20])

chi2,p = chisquare(observed,expected)

print("Chi Square Statistics : ", chi2)
print("P-value : ",p)

alpha = 0.05

if p<alpha:
  print("Reject the null hypothesis. The observed data does not fit the expected distribution.")
else:
  print("Failed to reject the null hypothesis. The observed data fits the expected distribution.")
# Out:
# Chi Square Statistics :  12.5
# P-value :  0.013995792487650894
# Reject the null hypothesis. The observed data does not fit the expected distribution.

# %% [markdown]
# 15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

df=5

sample = chi2.rvs(df,size=1000)

plt.hist(sample,bins=30,density=True,alpha=0.06,label='Histogram of Sample')

x=np.linspace(0,21,100)
y=chi2.pdf(x,df)
plt.plot(x,y,label='Chi-square Distribution')
plt.legend()
plt.show()

# %%
'''
The characteristics of Chi-square distribution are :
It is non-negative.
The shape changes with increasing degrees of freedom.
It approaches a normal distribution as degrees of freedom increase.
'''

# %% [markdown]
# 16. Implement an F-test using Python to compare the variances of two random samples.

# %%
import numpy as np
from scipy.stats import f

sample1 = np.random.normal(loc=0,scale=1,size=100)
sample2 = np.random.normal(loc=0,scale=2,size=100)

var1 = np.var(sample1,ddof=1)
var2 = np.var(sample2,ddof=1)

f_stat = var1/var2

df1 = len(sample1)-1
df2 = len(sample2)-1

p_value = 2*(1- f.cdf(f_stat,df1,df2))

print("F-statistic : ",f_stat)
print("P-value : ",p_value)

alpha = 0.05
if p_value < alpha:
  print("Reject the null hypothesis. The variances are likely different.")
else:
  print("Failed to reject the null hypothesis. The variances are likely equal.")
# Out:
# F-statistic :  0.31641428896411955
# P-value :  1.999999973610028
# Failed to reject the null hypothesis. The variances are likely equal.

# %% [markdown]
# 17. Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results.

# %%
import numpy as np
from scipy.stats import f_oneway
import matplotlib.pyplot as plt

np.random.seed(0)
group1 = np.random.normal(loc=0,scale=1,size=100)
group2 = np.random.normal(loc=1,scale=1,size=100)
group3 = np.random.normal(loc=2,scale=1,size=100)

f_stat,p_value = f_oneway(group1,group2,group3)

print("F-statistic : ",f_stat)
print("P-value : ",p_value)

alpha=0.05
if p_value < alpha:
  print("Reject the null hypothesis. The means are likely different.")
else:
  print("Failed to reject the null hypothesis. The means are likely equal.")
# Out:
# F-statistic :  88.00111635520777
# P-value :  9.708427651972184e-31
# Reject the null hypothesis. The means are likely different.

# %% [markdown]
# 18. Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results.

# %%
import numpy as np
from scipy.stats import f_oneway
import matplotlib.pyplot as plt

np.random.seed(0)
group1 = np.random.normal(loc=0,scale=1,size=100)
group2 = np.random.normal(loc=1,scale=1,size=100)
group3 = np.random.normal(loc=2,scale=1,size=100)

f_stat,p_value = f_oneway(group1,group2,group3)

print("F-statistic : ",f_stat)
print("P-value : ",p_value)

alpha=0.05

plt.boxplot([group1,group2,group3],labels=['Group1','Group2','Group3'])
plt.title('Box Plot')
plt.show()
# Out:
# F-statistic :  88.00111635520777
# P-value :  9.708427651972184e-31
# /tmp/ipython-input-24-697828509.py:17: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1,group2,group3],labels=['Group1','Group2','Group3'])

# %% [markdown]
# 19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA.

# %%
import numpy as np
from scipy.stats import f_oneway
import matplotlib.pyplot as plt

def check_assumptions(*data):
  plt.figure(figsize=(10,6))
  plt.boxplot(data,labels=[f'Group {i+1}' for i in range(len(data))])

  plt.title("Boxplot of the data")
  plt.show()

  f_stat,p_val = f_oneway(*data)
  print(f"Anova Test : F-Statistic = {f_stat:.2f}, p-value = {p_val:.2f}")

# %%
np.random.seed(0)
group1 = np.random.normal(loc=0,scale=1,size=100)
group2 = np.random.normal(loc=1,scale=1,size=100)
group3 = np.random.normal(loc=2,scale=1,size=100)

check_assumptions(group1,group2,group3)
# Out:
# /tmp/ipython-input-29-1078775300.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data,labels=[f'Group {i+1}' for i in range(len(data))])
# Anova Test : F-Statistic = 88.00, p-value = 0.00

# %% [markdown]
# 20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results.

# %%
import pandas as pd
import numpy as np

# Create sample data
data = pd.DataFrame({
    'Dependent_Variable': np.random.normal(loc=10, scale=2, size=60),
    'Factor_A': np.repeat(['Level1_A', 'Level2_A'], 30),
    'Factor_B': np.tile(np.repeat(['Level1_B', 'Level2_B'], 15), 2)
})

# Introduce an interaction effect for demonstration
data.loc[(data['Factor_A'] == 'Level1_A') & (data['Factor_B'] == 'Level1_B'), 'Dependent_Variable'] += 3

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Define the ANOVA model with interaction
model = ols('Dependent_Variable ~ C(Factor_A) + C(Factor_B) + C(Factor_A):C(Factor_B)', data=data).fit()

# Perform the ANOVA
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                              sum_sq    df          F    PR(>F)
# C(Factor_A)               46.931058   1.0  12.910049  0.000690
# C(Factor_B)               26.605240   1.0   7.318713  0.009025
# C(Factor_A):C(Factor_B)   29.456010   1.0   8.102918  0.006166
# Residual                 203.573145  56.0        NaN       NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate group means for visualization
mean_data = data.groupby(['Factor_A', 'Factor_B'])['Dependent_Variable'].mean().reset_index()

# Create an interaction plot
plt.figure(figsize=(8, 6))
sns.lineplot(x='Factor_A', y='Dependent_Variable', hue='Factor_B', data=mean_data, marker='o')
plt.title('Interaction Plot of Factor A and Factor B on Dependent Variable')
plt.xlabel('Factor A Levels')
plt.ylabel('Mean Dependent Variable')
plt.legend(title='Factor B')
plt.grid(True)
plt.show()

# %% [markdown]
# 21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

# Define degrees of freedom for different F-distributions
df_pairs = [(5, 10), (10, 5), (20, 20)]

# Generate x-values for the plot
x = np.linspace(0.01, 5, 500) # Start slightly above 0 as F-distribution is defined for positive values

plt.figure(figsize=(10, 6))

# Plot different F-distributions
for df1, df2 in df_pairs:
    pdf = f.pdf(x, df1, df2)
    plt.plot(x, pdf, label=f'df1={df1}, df2={df2}')

plt.title('F-Distribution Visualization')
plt.xlabel('F-statistic')
plt.ylabel('Probability Density Function (PDF)')
plt.grid(True)
plt.legend()
plt.show()

# %%
'''
In hypothesis testing, the F-test  is used to determine if there is a statistically significant difference
 between the variances of two or more populations or to test the overall significance of a regression model.
'''

# %% [markdown]
# 22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.

# %%
import numpy as np
from scipy.stats import f_oneway
import matplotlib.pyplot as plt

np.random.seed(0)
group1 = np.random.normal(loc=0,scale=1,size=100)
group2 = np.random.normal(loc=1,scale=1,size=100)
group3 = np.random.normal(loc=2,scale=1,size=100)

f_stat,p_value = f_oneway(group1,group2,group3)

print("F-statistic : ",f_stat)
print("P-value : ",p_value)

alpha=0.05

plt.boxplot([group1,group2,group3],labels=['Group1','Group2','Group3'])
plt.title('Box Plot')
plt.show()
# Out:
# F-statistic :  88.00111635520777
# P-value :  9.708427651972184e-31
# /tmp/ipython-input-35-697828509.py:17: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1,group2,group3],labels=['Group1','Group2','Group3'])

# %% [markdown]
# 23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means.

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt

np.random.seed(42)
population_mean = 10
population_std = 2
sample_size = 30
alpha = 0.05

sample = np.random.normal(population_mean, population_std, sample_size)

null_hypothesis_mean = 9
alternative_hypothesis_type = 'two-sided'

z_statistic, p_value = st.ttest_1samp(sample, null_hypothesis_mean)

if p_value < alpha:
    result = "Reject the null hypothesis"
else:
    result = "Fail to reject the null hypothesis"

# 3. Visualization
x = np.linspace(population_mean - 4*population_std, population_mean + 4*population_std, 1000)
y = st.norm.pdf(x, population_mean, population_std)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label="Normal Distribution")

# Shade the critical region(s)
if alternative_hypothesis_type == 'two-sided':
    critical_left = st.norm.ppf(alpha/2, population_mean, population_std)
    critical_right = st.norm.ppf(1 - alpha/2, population_mean, population_std)
    plt.fill_between(x, y, where=(x <= critical_left), color='red', alpha=0.5, label="Critical Region (Left)")
    plt.fill_between(x, y, where=(x >= critical_right), color='red', alpha=0.5, label="Critical Region (Right)")
elif alternative_hypothesis_type == 'larger':
    critical_right = st.norm.ppf(1 - alpha, population_mean, population_std)
    plt.fill_between(x, y, where=(x >= critical_right), color='red', alpha=0.5, label="Critical Region (Right)")
elif alternative_hypothesis_type == 'smaller':
    critical_left = st.norm.ppf(alpha, population_mean, population_std)
    plt.fill_between(x, y, where=(x <= critical_left), color='red', alpha=0.5, label="Critical Region (Left)")

# Plot the sample mean
plt.axvline(sample.mean(), color='green', linestyle='dashed', linewidth=1, label=f"Sample Mean: {sample.mean():.2f}")

# Annotate the plot with results
plt.title(f"One-Sample Z-Test Results \n {result} (p-value = {p_value:.3f})")
plt.xlabel("Value")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()

print(f"Sample Mean: {sample.mean():.2f}")
print(f"Z-statistic: {z_statistic:.2f}")
print(f"P-value: {p_value:.3f}")
print(f"Result: {result}")
# Out:
# Sample Mean: 9.62
# Z-statistic: 1.90
# P-value: 0.068
# Result: Fail to reject the null hypothesis

# %% [markdown]
# 24. Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results.

# %%
import numpy as np
import scipy.stats as stats

def chi_square_variance_test(sample_data, hypothesized_variance, alpha=0.05):
  sample_size = len(sample_data)
  sample_variance = np.var(sample_data, ddof=1)  # Use ddof=1 for sample variance

  chi_squared_stat = (sample_size - 1) * sample_variance / hypothesized_variance
  degrees_of_freedom = sample_size - 1
  p_value = 1 - stats.chi2.cdf(chi_squared_stat, degrees_of_freedom)

  critical_value = stats.chi2.ppf(1 - alpha, degrees_of_freedom)

  if chi_squared_stat > critical_value:
    decision = "Reject the null hypothesis"
  else:
    decision = "Fail to reject the null hypothesis"

  return chi_squared_stat, p_value, critical_value, decision

# %%
# Example usage
sample_data = [12, 15, 18, 20, 22, 25, 28, 30, 32, 35]
hypothesized_variance = 50
alpha = 0.05

test_statistic, p_value, critical_value, decision = chi_square_variance_test(sample_data, hypothesized_variance, alpha)

print(f"Chi-square statistic: {test_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Critical value: {critical_value:.4f}")
print(f"Decision: {decision}")
# Out:
# Chi-square statistic: 10.3620
# P-value: 0.3220
# Critical value: 16.9190
# Decision: Fail to reject the null hypothesis

# %% [markdown]
# 25. Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.

# %%
import numpy as np
from statsmodels.stats.proportion import proportions_ztest

def two_proportion_z_test(successes1, observations1, successes2, observations2, alpha=0.05, alternative='two-sided'):
    count = np.array([successes1, successes2])
    nobs = np.array([observations1, observations2])

    z_statistic, p_value = proportions_ztest(count, nobs, alternative=alternative)

    if p_value < alpha:
        decision = "Reject the Null Hypothesis (H0): There is a significant difference in proportions."
    else:
        decision = "Fail to Reject the Null Hypothesis (H0): No significant difference in proportions."

    return z_statistic, p_value, decision

# Example Usage:
clicks_campaign_A = 120
total_views_campaign_A = 500

clicks_campaign_B = 90
total_views_campaign_B = 400

z_stat, p_val, test_decision = two_proportion_z_test(
    clicks_campaign_A, total_views_campaign_A,
    clicks_campaign_B, total_views_campaign_B
)

print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_val:.4f}")
print(f"Decision: {test_decision}")
# Out:
# Z-statistic: 0.5287
# P-value: 0.5970
# Decision: Fail to Reject the Null Hypothesis (H0): No significant difference in proportions.

# %% [markdown]
# 26. Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

worker1 = [18,34,17,20,56,23,12,56,12,35,57]
worker2 = [28,44,19,32,56,80,52,26,52,30,29]

f_stats = np.var(worker1)/np.var(worker2)
f_stats
# Out:
# np.float64(1.0008469312856416)

# %%
df1 = len(worker1) - 1
df2 = len(worker2) - 1
alpha = 0.05
f_critical = stats.f.ppf(q=1-alpha, dfn = df1 , dfd = df2)

f_critical
# Out:
# np.float64(2.9782370160823213)

# %%
if f_stats < f_critical :
  print("Reject the Null Hypothesis.")
else :
  print('Failed to reject the null hypothesis.')
# Out:
# Reject the Null Hypothesis.

# %%
#Visualisation
from scipy.stats import f
x =  np.linspace(0, 10, 500)
pdf = f.pdf(x, df1, df1)

plt.figure(figsize=(8, 5))
plt.plot(x, pdf, label=f'F-distribution (dfn={df1}, dfd={df2})')
plt.title('F-distribution and F-test Visualization')
plt.xlabel('F-value')
plt.ylabel('Probability Density')
plt.legend()
plt.show()

# %% [markdown]
# 27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results.

# %%
import seaborn as sns
data = sns.load_dataset("titanic")
data.head()

import pandas as pd
data_table = pd.crosstab(data["sex"],data["class"])
data_table
# Out:
# class   First  Second  Third
# sex
# female     94      76    144
# male      122     108    347

# %%
observed_values = data_table.values
observed_values
# Out:
# array([[ 94,  76, 144],
#        [122, 108, 347]])

# %%
import scipy.stats as stats
from scipy.stats import chi2

statistic, pvalue, dof, expected_values = stats.chi2_contingency(observed_values)
print("dof = ",dof,"\npvalue = ", pvalue, "\n",expected_values)
# Out:
# dof =  2
# pvalue =  0.00020638864348233114
#  [[ 76.12121212  64.84399551 173.03479237]
#  [139.87878788 119.15600449 317.96520763]]

# %%
chi2_test = sum([(o-e)**2/e for o,e in zip(observed_values,expected_values)])
chi2_test
# Out:
# array([6.48443796, 2.96380403, 7.52325711])

# %%
chi_stat = chi2_test[0] +chi2_test[1] +chi2_test[2]
chi_stat
# Out:
# np.float64(16.97149909551711)

# %%
alpha = 0.05
chi_critic = chi2.ppf(1-alpha,dof)
chi_critic
# Out:
# np.float64(5.991464547107979)

# %%
if chi_stat < chi_critic :
  print("Reject the Null Hypothesis.")
else :
  print('Failed to reject the null hypothesis.')
# Out:
# Failed to reject the null hypothesis.

# %% [markdown]
# *****************************************************************************************
